# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'clean_csv/flat_clean.csv',index_col='Unnamed: 0')
df.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            apna enclave
# 2              2 BHK Flat in Sohna          flat  tulsiani easy in homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     smart world orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        parkwood westend
#
#    price  price_per_sqft     area                            areaWithType  \
# 0   0.45          5000.0   900.00          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.03          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.06          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.00        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.12  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom balcony additionalRoom  \
# ...

# %%
df1=pd.read_csv(r'clean_csv/independant_house.csv',index_col='Unnamed: 0')
df1.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon    ind. house
# 1  5 Bedroom House for sale in Sector 21A Faridabad    ind. house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1    ind. house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon    ind. house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1    ind. house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1               NaN   5.70        105751.0   539.0
# 2               NaN   2.10         38251.0   549.0
# 3               NaN   5.00         43066.0  1161.0
# 4               NaN   3.00         53763.0   558.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)      5.0       4.0     3+
# 1   Plot area 539(50.07 sq.m.)      5.0       4.0      2
# 2       Plot area 61(51 sq.m.)     10.0      10.0     3+
# ...

# %%
df.shape
# Out:
# (2864, 20)

# %%
df.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'price', 'price_per_sqft',
#        'area', 'areaWithType', 'bedRoom', 'bathroom', 'balcony',
#        'additionalRoom', 'address', 'floorNum', 'facing', 'agePossession',
#        'nearbyLocations', 'description', 'furnishDetails', 'features',
#        'rating'],
#       dtype='object')

# %%
df1.shape
# Out:
# (945, 20)

# %%
df1.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'price', 'price_per_sqft',
#        'area', 'areaWithType', 'bedRoom', 'bathroom', 'balcony',
#        'additionalRoom', 'address', 'floorNum', 'facing', 'agePossession',
#        'nearbyLocations', 'description', 'furnishDetails', 'features',
#        'rating'],
#       dtype='object')

# %%
combine_df=pd.concat([df,df1])

# %%
combine_df.to_csv(r'dataset\combine_csv_unclean.csv')
